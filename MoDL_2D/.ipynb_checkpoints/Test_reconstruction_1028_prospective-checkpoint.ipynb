# %%
# %matplotlib notebook
import os, sys
import logging
import random
import shutil
import time
import argparse
import numpy as np
import sigpy.plot as pl
import torch
import torchvision
from tensorboardX import SummaryWriter
from torch.nn import functional as F
from torch.utils.data import DataLoader
from utils.flare_utils import torch2np
import h5py
from utils.resnet2p1d import generate_model
# import matplotlib
# matplotlib.use('TkAgg')
import sigpy as sp
# import custom libraries
from utils import transforms as T
from utils import subsample as ss
from utils import complex_utils as cplx

# import custom classes
from utils.datasets import SliceData
from utils.subsample import VDktMaskFunc
from models.unrolled3D.unrolled3D_MoDL import UnrolledModel as UnrolledModelM
from models.unrolled3D.unrolled3D_MoDL_MELD import UnrolledModel as UnrolledModelMELD

# UnrolledModelM = UnrolledModel
from models.unrolled3D.unrolled3D import UnrolledModel
# os.environ["CUDA_VISIBLE_DEVICES"]="9"
device = torch.device('cuda:3')
# device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cfl

# %%
kspace = cfl.readcfl("/mikQNAP/Cardiac_cine_prospective_dataset/Exam2455-Volunteer/Series18/cine.tmp-recon.3D/ks")
maps = cfl.readcfl("/mikQNAP/Cardiac_cine_prospective_dataset/Exam2455-Volunteer/Series18/cine.tmp-recon.3D/maps")
im_pics = cfl.readcfl("/mikQNAP/Cardiac_cine_prospective_dataset/Exam2455-Volunteer/Series18/cine.tmp-recon.3D/im.pics")

# %%
pl.ImagePlot(im_pics)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
kspace = cfl.readcfl("/mikQNAP/Cardiac_cine_prospective_dataset/Exam2455-Volunteer/Series10/cine.tmp-recon.21108/ks")[:,:169,...]
maps = cfl.readcfl("/mikQNAP/Cardiac_cine_prospective_dataset/Exam2455-Volunteer/Series10/cine.tmp-recon.21108/maps.full.0")[:,:169,...]

# %%
kspace.shape
# Out:
# (204, 170, 5, 8, 1, 1, 1, 20)

# %%
a = (abs(kspace_correct)>0).astype(float)

# %%
a

# %%
pl.ImagePlot(kspace_correct)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
kspace_correct = kspace.squeeze()[:,:,3,:,:].transpose(0,1,3,2)
mask = abs(kspace_correct)>0
maps_correct = maps[:,:,3,:,0][...,None,:,None]
masked_kspace = cplx.to_tensor(kspace_correct).unsqueeze(0)
maps   = cplx.to_tensor(maps_correct).unsqueeze(0)
mask = torch.tensor(mask[None,:,:,:,0][...,None,None].astype(np.float32))

# %%
A = T.SenseModel(maps)

# Compute normalization factor (based on 95% max signal level in view-shared dataa)
averaged_kspace = T.time_average(masked_kspace, dim=3)
image = A(averaged_kspace, adjoint=True)
magnitude_vals = cplx.abs(image).reshape(-1)
k = int(round(0.05 * magnitude_vals.numel()))
scale = torch.min(torch.topk(magnitude_vals, k).values)

# Normalize k-space and target images
masked_kspace /= scale
# target /= scale
mean = torch.tensor([0.0], dtype=torch.float32)
std = scale

# %%
# compute scaling factor (only need for CS right now)
    ncalib = 32
    kspace_lowres = recon.crop(kspace_avg, [-1, -1, ncalib, ncalib])
    image_lowres = fftc.ifft2c(kspace_lowres).astype(np.complex64)
    image_lowres = recon.sumofsq(image_lowres, axis=0) * ncalib / np.sqrt(nkx*nky) # (num_slices, nky, nkx)
    scaling = np.sort(image_lowres.reshape((num_slices, ncalib**2)), axis=1)[:, int(0.95*ncalib**2)]

# %%
input_torch = masked_kspace.to(device)
maps_torch = maps.to(device)

# %%
A = T.SenseModel(maps_torch)
zf_image = A(input_torch,adjoint=True)

# %%
with torch.no_grad():
#     start = time.time()
    model.initiate(input_torch,maps_torch)
    start = time.time()
    output = model()
    
#     output = model(input_torch, maps_torch, init_image=None)
#     print(time.time()-start)
    start = time.time()

    output_modl = model_modl(input_torch, maps_torch, init_image=None)    
    print(time.time()-start)
# Out:
# 1.003770112991333

# %%
output_modl_np = torch2np(output_modl)
output_np = torch2np(output)

# %%
im_pics_slice = im_pics[:,:,3,0,0,0,0,:][None,...,None]

# %%
output_all.shape
# Out:
# (3, 204, 170, 20, 1)

# %%
output_all = np.concatenate((im_pics_slice/1e8,output_modl_np,output_np))

# %%
# %matplotlib notebook

# %%
pl.ImagePlot(output_all)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import ConnectionPatch
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.gridspec as gridspec

# %%
# %matplotlib inline

# %%
fig, (ax_0) = plt.subplots(nrows=1, ncols=3, sharex=False,
                                    figsize=(15,6))

gs1 = gridspec.GridSpec(1, 3)
gs1.update(wspace=0.025, hspace=0.05) # set the spacing between axes. 
plt.subplots_adjust(wspace=None, hspace=None)
ax = ax_0[0]
mt = 0
# im_contrast = abs(im_all_all[:,mt,111,:])
# im_contrast = abs(im_all_all[160,mt,:,:]).transpose(1,0)
# im_contrast = abs(im_all_all[:,mt,:,])

# im_contrast = abs(im_all_all[:,mt,111,:])
# x_lims = (120,180) # pro1 sag
# y_lims = (185,125)
im_contrast = abs(output_all[mt,...,15,0])
im_gt = abs(output_all[0,...,15,0])
x_lims = (50,90) # pro1 sag
y_lims = (105,65)

ax.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_gt.max()/2.5])
ax.axis("off")
axins = ax.inset_axes([0.57, 0, 0.4, 0.4])
# axins = zoomed_inset_axes(ax, 6, loc=1)  # zoom = 6
axins.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_gt.max()/2.5])
axins.set_xlim(*x_lims)
axins.set_ylim(*y_lims)
mark_inset(ax, axins, loc1=1, loc2=2, fc="none", lw=3, ec='orange')
axins.set_yticklabels([])
axins.set_xticklabels([])
axins.tick_params(axis = "x", which = "both", bottom = False, top = False)
axins.tick_params(axis = "y", which = "both", left = False, right = False)
for at in ['top','bottom','left','right']:
    axins.spines[at].set_linewidth(3)
    axins.spines[at].set_color("orange")
    
ax = ax_0[1]
mt = 1
# im_contrast = abs(im_all_all[:,mt,111,:])
# im_contrast = abs(im_all_all[160,mt,:,:]).transpose(1,0)
# im_contrast = abs(im_all_all[:,mt,:,])

# im_contrast = abs(im_all_all[:,mt,111,:])
# x_lims = (120,180) # pro1 sag
# y_lims = (185,125)
im_contrast = abs(output_all[mt,...,15,0])
im_gt = abs(output_all[0,...,15,0])
x_lims = (50,90) # pro1 sag
y_lims = (105,65)

ax.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_gt.max()/2.5])
ax.axis("off")
axins = ax.inset_axes([0.57, 0, 0.4, 0.4])
# axins = zoomed_inset_axes(ax, 6, loc=1)  # zoom = 6
axins.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_gt.max()/2.5])
axins.set_xlim(*x_lims)
axins.set_ylim(*y_lims)
mark_inset(ax, axins, loc1=1, loc2=2, fc="none", lw=3, ec='orange')
axins.set_yticklabels([])
axins.set_xticklabels([])
axins.tick_params(axis = "x", which = "both", bottom = False, top = False)
axins.tick_params(axis = "y", which = "both", left = False, right = False)
for at in ['top','bottom','left','right']:
    axins.spines[at].set_linewidth(3)
    axins.spines[at].set_color("orange")
    
ax = ax_0[2]
mt = 2
# im_contrast = abs(im_all_all[:,mt,111,:])
# im_contrast = abs(im_all_all[160,mt,:,:]).transpose(1,0)
# im_contrast = abs(im_all_all[:,mt,:,])

# im_contrast = abs(im_all_all[:,mt,111,:])
# x_lims = (120,180) # pro1 sag
# y_lims = (185,125)
im_contrast = abs(output_all[mt,...,15,0])
im_gt = abs(output_all[0,...,15,0])
x_lims = (50,90) # pro1 sag
y_lims = (105,65)

ax.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_gt.max()/2.5])
ax.axis("off")
axins = ax.inset_axes([0.57, 0, 0.4, 0.4])
# axins = zoomed_inset_axes(ax, 6, loc=1)  # zoom = 6
axins.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_gt.max()/2.5])
axins.set_xlim(*x_lims)
axins.set_ylim(*y_lims)
mark_inset(ax, axins, loc1=1, loc2=2, fc="none", lw=3, ec='orange')
axins.set_yticklabels([])
axins.set_xticklabels([])
axins.tick_params(axis = "x", which = "both", bottom = False, top = False)
axins.tick_params(axis = "y", which = "both", left = False, right = False)
for at in ['top','bottom','left','right']:
    axins.spines[at].set_linewidth(3)
    axins.spines[at].set_color("orange")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-473-41dedfcdf248> in <module>
#       3 gs1.update(wspace=0.025, hspace=0.05) # set the spacing between axes.
#       4 fig, (ax_0) = plt.subplots(nrows=1, ncols=3, sharex=False,
# ----> 5                                     figsize=(15,6),gridspec_kw=gs1)
#       6 plt.subplots_adjust(wspace=None, hspace=None)
#       7 ax = ax_0[0]
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1218     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1219                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1220                        gridspec_kw=gridspec_kw)
#    1221     return fig, axs
#    1222
#
# ...

# %%
mt = 1
# im_contrast = abs(im_all_all[:,mt,111,:])
# im_contrast = abs(im_all_all[160,mt,:,:]).transpose(1,0)
# im_contrast = abs(im_all_all[:,mt,:,])

# im_contrast = abs(im_all_all[:,mt,111,:])
# x_lims = (120,180) # pro1 sag
# y_lims = (185,125)
im_contrast = abs(output_all[mt,...,15,0])
x_lims = (50,90) # pro1 sag
y_lims = (105,65)
orientation = "coronal"
if mt == 1:
    name = "modl_4_unrolls"
if mt == 0:
    name = "PICS"
if mt == 2:
    name = "modl_10_unrolls"
if mt == 3:
    name = "3DMODL"
# x_lims = (130,190) # Pro2 sagittal
# y_lims = (180,120)
# x_lims = (100,160) # Pro2 axial
# y_lims = (190,130)
fig, ax = plt.subplots(figsize=[6, 7])
ax.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_contrast.max()])
ax.axis("off")
axins = ax.inset_axes([0.57, 0, 0.4, 0.4])
# axins = zoomed_inset_axes(ax, 6, loc=1)  # zoom = 6
axins.imshow(im_contrast,cmap="gray",interpolation="lanczos",clim =[0,im_contrast.max()])
axins.set_xlim(*x_lims)
axins.set_ylim(*y_lims)
mark_inset(ax, axins, loc1=1, loc2=2, fc="none", lw=3, ec='orange')
axins.set_yticklabels([])
axins.set_xticklabels([])
axins.tick_params(axis = "x", which = "both", bottom = False, top = False)
axins.tick_params(axis = "y", which = "both", left = False, right = False)
for at in ['top','bottom','left','right']:
    axins.spines[at].set_linewidth(3)
    axins.spines[at].set_color("orange")
# plt.savefig("Figures/Cine_DIR_pro_slice1_final_%s_%s.png"%(orientation,name),transparent=True, format='png',bbox_inches='tight', pad_inches=0,dpi=200,quality=95)        

# plt.savefig("Figures/%s_patient_2_%s.png"%(contrast,name),transparent=True, format='png',bbox_inches='tight', pad_inches=0,dpi=600,quality=95)        
# ax.indicate_inset_zoom(axins,edgecolor='r',lw=2,linewidth=2)
# axins.axis("off")
# pl.ImagePlot(imag_all*mask,interpolation="lanczos")
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Load the checkpoint:
# checkpoint_file = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10281_ufloss0/model_epoch1000.pt"
checkpoint_file = "/mikQNAP/cardiac_cine/summary/train-3D_MELD_10steps_2resblocks_32features_MoDLflag0_CGsteps_8date_11041_ufloss0/model_epoch1390.pt"
# checkpoint_file = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10281_ufloss0/model_epoch1000.pt"

checkpoint = torch.load(checkpoint_file,map_location=device)
args = checkpoint['args']
# args.device_num='-1'
# args.device='cpu'
if args.modl_flag == True:
    if args.meld_flag == True:
#         print("f")
        model = UnrolledModelMELD(args).to(device)
    else:
        model = UnrolledModelM(args).to(device)
else:
    model = UnrolledModel(args).to(device)
model.load_state_dict(checkpoint['model'])
print(checkpoint['epoch'])
# Out:
# No shared weights
# 1390

# %%
# checkpoint_file_modl = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10282_ufloss0/model_epoch1000.pt"

checkpoint_file_modl = "/mikQNAP/cardiac_cine/summary/train-3D_MELD_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_11042_ufloss0/model_epoch500.pt"
checkpoint_modl = torch.load(checkpoint_file_modl,map_location=device)
args_modl = checkpoint_modl['args']
args_modl.modl_lamda = 0.05
# args_modl.conv_type = 'conv3d'
# args_modl.device_num='-1'
# args_modl.device='cpu'
if args_modl.modl_flag == True:
    model_modl = UnrolledModelM(args_modl).to(device)
else:
    model_modl = UnrolledModel(args_modl).to(device)
model_modl.load_state_dict(checkpoint_modl['model'])
print(checkpoint_modl['epoch'])
# Out:
# No shared weights
# 500

# %%
# slice =4
t = 0
for ddir in os.listdir(home_dir):
    
    da = h5py.File(home_dir+ddir, 'r')
    slice_num = da['target'].shape[0]
    for slice in range(slice_num):
        print(t)
        kspace = np.array(da['kspace'])[slice,...]
        maps = np.array(da['maps'])[slice,...]
        target = np.array(da['target'] )[slice,...]

        dev_mask = VDktMaskFunc([13,15])
        maps = maps[...,0][...,None]
        target = target[...,0][...,None]
        # Convert everything from numpy arrays to tensors
        kspace = cplx.to_tensor(kspace).unsqueeze(0)
        maps   = cplx.to_tensor(maps).unsqueeze(0)
        target = cplx.to_tensor(target).unsqueeze(0)
        norm = torch.sqrt(torch.mean(cplx.abs(target)**2))
        seed = None
        # kspace, target = self.augment(kspace, target, seed)
        #         pl.ImagePlot(kspace)
        #         pl.ImagePlot(target)
        # Undersample k-space data
        masked_kspace, mask = ss.subsample(kspace, dev_mask, seed)
        A = T.SenseModel(maps)

        # Compute normalization factor (based on 95% max signal level in view-shared dataa)
        averaged_kspace = T.time_average(masked_kspace, dim=3)
        image = A(averaged_kspace, adjoint=True)
        magnitude_vals = cplx.abs(image).reshape(-1)
        k = int(round(0.05 * magnitude_vals.numel()))
        scale = torch.min(torch.topk(magnitude_vals, k).values)

        # Normalize k-space and target images
        masked_kspace /= scale
        target /= scale
        mean = torch.tensor([0.0], dtype=torch.float32)
        std = scale
        input_torch = masked_kspace.to(device)
        maps_torch = maps.to(device)
        target_torch = target.to(device)
        with torch.no_grad():
        #     start = time.time()
            model.initiate(input_torch,maps_torch)
            start = time.time()
            output = model()

        #     output = model(input_torch, maps_torch, init_image=None)
        #     print(time.time()-start)
            start = time.time()

            output_modl = model_modl(input_torch, maps_torch, init_image=None)    
            print(time.time()-start)
        A = T.SenseModel(maps_torch)
        zf_image = A(input_torch,adjoint=True)
        output_np = torch2np(output)
        # output_modl_ufloss_np = torch2np(output_modl_ufloss)
        output_modl_np = torch2np(output_modl)
        output_gt = torch2np(target)
        output_zf = torch2np(zf_image)
        bart_kspace = cplx.to_numpy(masked_kspace)
        bart_maps = cplx.to_numpy(maps)
        frames = bart_kspace.shape[3]
        for j in range(frames):
            bart_slice = bart_kspace[0,:,:,None,j,:]
            maps_slice = bart_maps[0,:,:,None,0,:,0]
            recon_l1wavelet = bart.bart(1,"pics -r 0.02 -l1 -S",bart_slice,maps_slice)[:,:,None]
            if j == 0:
                recon_bart_l1 = recon_l1wavelet
            else:
                recon_bart_l1 = np.concatenate((recon_bart_l1,recon_l1wavelet),-1)

        output_all = np.concatenate((output_gt,recon_bart_l1[None,...,None],output_np,output_modl_np)).squeeze()
        output_all = sp.resize(output_all,(4, 60, 60, 20))
        if t == 0:
            output_allslice = output_all[None,...]
            t+=1
        else:
            output_allslice = np.concatenate((output_allslice,output_all[None,...]))
            t+=1
#         break
#     break
# Out:
# 0
# 0.2797412872314453
# 1
# 0.2801826000213623
# 2
# 0.26039862632751465
# 3
# 0.259655237197876
# 4
# 0.26021432876586914
# 5
# 0.26315784454345703
# 6
# 0.2687249183654785
# 7
# 0.26236414909362793
# 8
# 0.26305198669433594
# 9
# 0.26190686225891113
# 10
# 0.2625091075897217
# 11
# 0.2629702091217041
# 12
# 0.26582884788513184
# 13
# 0.26228833198547363
# 14
# 0.2633354663848877
# 15
# 0.28295111656188965
# 16
# 0.30423545837402344
# 17
# 0.30104970932006836
# 18
# 0.30214762687683105
# 19
# 0.2872738838195801
# 20
# 0.28325390815734863
# 21
# 0.28267979621887207
# 22
# 0.2832670211791992
# 23
# 0.2856557369232178
# 24
# 0.2836642265319824
# 25
# 0.2830538749694824
# 26
# 0.2882649898529053
# 27
# 0.2835357189178467
# 28
# 0.2863502502441406
# 29
# 0.2844569683074951
# 30
# 0.2833728790283203
# 31
# 0.2856290340423584
# 32
# 0.2838621139526367

# %%
output_allslice.shape
# Out:
# (33, 4, 60, 60, 20)

# %%
np.save("all_images_20210223.npy",output_allslice)

# %%
from skimage.metrics import structural_similarity as ssim

# %%
def nmrse(x,gt):
    return np.linalg.norm(x-gt)/np.linalg.norm(gt)
def ssim_k(x,gt):
    return ssim(abs(x),abs(gt),data_range=abs(gt).max() - abs(gt).min())
def psnr(x,gt):
    mse = np.linalg.norm(x-gt)**2/(x.shape[0]*x.shape[1])
#     print(mse)
    return 20 * np.log10(abs(gt).max()/np.sqrt(mse)) 
def psnr_dynamic(x,gt):
    frames = gt.shape[-1]
    psnr_all = 0
    for j in range(frames):
        psnr_all += psnr(x[:,:,j],gt[:,:,j])
    return psnr_all/frames
def ssim_dynamic(x,gt):
    frames = gt.shape[-1]
    ssim_all = 0
    for j in range(frames):
        ssim_all += ssim_k(x[:,:,j],gt[:,:,j])
    return ssim_all/frames

# %%
output_allslice.shape
# Out:
# (33, 4, 60, 60, 20)

# %%
psnr_allslices = list([])
for t in range(output_allslice.shape[0]):
    psnr_all = list([])
    psnr_all.append(psnr_dynamic(output_allslice[t,1,...],output_allslice[t,0,...]))
    psnr_all.append(psnr_dynamic(output_allslice[t,2,...],output_allslice[t,0,...]))    
    psnr_all.append(psnr_dynamic(output_allslice[t,3,...],output_allslice[t,0,...]))  
    psnr_allslices.append(psnr_all)
psnr_allslices = np.array(psnr_allslices)

# %%
ssim_allslices = list([])
for t in range(output_allslice.shape[0]):
    ssim_all = list([])
    ssim_all.append(ssim_dynamic(output_allslice[t,1,...],output_allslice[t,0,...]))
    ssim_all.append(ssim_dynamic(output_allslice[t,2,...],output_allslice[t,0,...]))    
    ssim_all.append(ssim_dynamic(output_allslice[t,3,...],output_allslice[t,0,...]))  
    ssim_allslices.append(ssim_all)
ssim_allslices = np.array(ssim_allslices)

# %%
np.mean(ssim_allslices,0)
# Out:
# array([0.59968775, 0.88757214, 0.87057469])

# %%
np.std(ssim_allslices,0)
# Out:
# array([0.07779906, 0.0416998 , 0.04148752])

# %%
psnr_allslices
# Out:
# [[13.042226662785367, 18.62170963980435, 19.844751112088833],
#  [17.90991295112532, 25.529121508055358, 26.00185126233644],
#  [20.278381423075096, 28.385380148772718, 27.28946664721273],
#  [17.862977588275832, 26.684192259366217, 25.801298209235604],
#  [17.59480714366114, 25.935031844770094, 25.262623167483948],
#  [21.831450080398096, 29.2307644825488, 28.733055429157254],
#  [22.48855552392368, 28.54135826757038, 28.044624602422903],
#  [23.188131573372647, 29.448979723595905, 29.01817172572409],
#  [20.72119512183683, 27.60962006290245, 27.129426064567006],
#  [21.007202503540505, 27.834281983218226, 27.561841522737126],
#  [21.103671734768838, 27.95636371899198, 27.646353136240947],
#  [22.971687350701234, 30.715397663252382, 30.179224863715426],
#  [23.23304078966661, 31.616611647821713, 30.960560210929337],
#  [22.83864517511919, 31.441132512936605, 31.041368051159157],
#  [22.49478792472395, 31.329533808827613, 30.614647666880188],
# ...

# %%
psnr_dynamic(output_allslice[12,3,...],output_allslice[12,0,...])
# Out:
# 30.960560210929337

# %%
import bart

# %%
pl.ImagePlot(output_allslice)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
output_np = torch2np(output)
output_modl_ufloss_np = torch2np(output_modl_ufloss)
output_modl_np = torch2np(output_modl)
output_gt = torch2np(target)
output_zf = torch2np(zf_image)
output_all = np.concatenate((output_gt,output_np,output_modl_np))

# %%
def compute_metrics(output,target_torch):
    cplx_error = cplx.abs(output - target_torch)
    cplx_l1 = torch.mean(cplx_error)
    cplx_l2 = torch.sqrt(torch.mean(cplx_error**2))
    cplx_psnr = 20 * torch.log10(scale / cplx_l2)
    return cplx_l1,cplx_l2,cplx_psnr

# %%
compute_metrics(output,target_torch)
# Out:
# (tensor(0.0418, device='cuda:3'),
#  tensor(0.0529, device='cuda:3'),
#  tensor(182.6911))

# %%
compute_metrics(output_modl,target_torch)
# Out:
# (tensor(0.0440, device='cuda:3'),
#  tensor(0.0557, device='cuda:3'),
#  tensor(182.2437))

# %%
compute_metrics(output_modl_ufloss,target_torch)
# Out:
# (tensor(0.0484, device='cuda:3'),
#  tensor(0.0604, device='cuda:3'),
#  tensor(181.5480))

# %%
np.save("output_all.npy",output_all)

# %%
patch = np.load("/home/kewang/patch_cine_1028_400_20/patch_data/0_0_310.npy")

# %%
pl.ImagePlot(patch,interpolation="lanczos")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
(np.log(1/0.05)/(2*10000))**(0.5)
# Out:
# 0.012238734153404082

# %%
output_all.shape
# Out:
# (4, 64, 180, 20, 1)

# %%
image = sp.resize(output_all,(4,64,100,20,1))

# %%
import matplotlib.pyplot as plt

# %%
k = 2
orientation = "xy"
if k == 0:
    method = "gt"
if k == 1:
    method = "10unrolls"
if k == 2:
    method = "5unrolls"
fig, ax = plt.subplots(figsize=[6, 6])
im = abs(image)[k,:,:,10,0][::-1,:]
# im = im.transpose(1,0)
ax.imshow(im,cmap="gray",interpolation="lanczos",clim =[0,im.max()])
ax.axis("off")
plt.savefig("Figures/2D_cardiac_1214_%s_%s.png"%(orientation,method),transparent=True, format='png',bbox_inches='tight', pad_inches=0,dpi=600,quality=95)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
pl.ImagePlot(sp.resize(output_all,(4,64,100,20,1)),interpolation="lanczos")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
input_torch.shape
# Out:
# tensor([[[[[-0.1057, -0.1347]],
#
#           [[-0.1067, -0.1170]],
#
#           [[-0.1040, -0.1251]],
#
#           ...,
#
#           [[-0.0994, -0.1283]],
#
#           [[-0.1158, -0.1394]],
#
#           [[-0.1084, -0.1458]]],
#
#
#          [[[-0.0916, -0.1445]],
#
#           [[-0.1020, -0.1759]],
#
#           [[-0.1086, -0.1519]],
#
#           ...,
#
#           [[-0.1148, -0.1750]],
#
#           [[-0.1053, -0.1544]],
#
#           [[-0.0951, -0.1587]]],
#
#
#          [[[-0.1335,  0.0226]],
#
#           [[-0.1100,  0.0152]],
#
#           [[-0.1320,  0.0156]],
#
#           ...,
#
#           [[-0.1168,  0.0008]],
#
#           [[-0.1077,  0.0238]],
#
#           [[-0.1105,  0.0315]]],
#
#
#          ...,
#
#
#          [[[-0.0780, -0.0990]],
#
#           [[-0.0523, -0.0996]],
#
#           [[-0.0854, -0.1068]],
#
#           ...,
#
#           [[-0.0732, -0.0930]],
#
#           [[-0.0608, -0.0933]],
#
#           [[-0.0683, -0.1006]]],
#
#
# ...

# %%
args
# Out:
# Namespace(accelerations=[10, 15], batch_size=1, checkpoint=None, circular_pad=True, conv_type='conv2p1d', data_parallel=False, data_path='/home/kewang/cardiac_cine', device='cuda', device_num='2', drop_prob=0.0, exp_dir='/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10281_ufloss0', fix_step_size=True, kernel_size=3, loss_normalized='True', loss_type=2, loss_uflossdir=None, lr=0.0001, lr_gamma=0.5, lr_step_size=500, modl_flag=False, modl_lamda=0.05, num_cg_steps=6, num_emaps=1, num_epochs=2000, num_features=32, num_grad_steps=5, num_resblocks=2, patch_size=64, report_interval=10, resume=False, sample_rate=1.0, seed=42, share_weights=False, slwin_init=True, ufloss_weight=2, uflossfreq=10, weight_decay=0.0)

# %%
pl.ImagePlot(image)
# Out:
# <img src="data:image/png;base64,..." width="640">
