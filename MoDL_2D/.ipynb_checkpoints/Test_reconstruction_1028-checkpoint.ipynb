# %%
# %matplotlib notebook
import os, sys
import logging
import random
import shutil
import time
import argparse
import numpy as np
import sigpy.plot as pl
import torch
import torchvision
from tensorboardX import SummaryWriter
from torch.nn import functional as F
from torch.utils.data import DataLoader
from utils.flare_utils import torch2np
import h5py
from utils.resnet2p1d import generate_model
# import matplotlib
# matplotlib.use('TkAgg')
import sigpy as sp
# import custom libraries
from utils import transforms as T
from utils import subsample as ss
from utils import complex_utils as cplx

# import custom classes
from utils.datasets import SliceData
from utils.subsample import VDktMaskFunc
from models.unrolled3D.unrolled3D_MoDL import UnrolledModel as UnrolledModelM
from models.unrolled3D.unrolled3D_MoDL_MELD import UnrolledModel as UnrolledModelMELD

# UnrolledModelM = UnrolledModel
from models.unrolled3D.unrolled3D import UnrolledModel
# os.environ["CUDA_VISIBLE_DEVICES"]="9"
device = torch.device('cuda:0')
# device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
# %load_ext autoreload
# %autoreload 2

# %%
slice =4
da = h5py.File("/home/kewang/cardiac_cine/validate/Exam2200_Series5_Phases20.h5", 'r')
kspace = np.array(da['kspace'])[slice,...]
maps = np.array(da['maps'])[slice,...]
target = np.array(da['target'] )[slice,...]

# %%
kspace.shape
# Out:
# (64, 180, 20, 8)

# %%
pl.ImagePlot(target,interpolation="lanczos")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dev_mask = VDktMaskFunc([4,5])

masked_kspace, mask = ss.subsample(kspace, dev_mask, seed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-b672a13ef442> in <module>
#       1 dev_mask = VDktMaskFunc([4,5])
#       2
# ----> 3 masked_kspace, mask = ss.subsample(kspace, dev_mask, seed)
#
# ~/Cine_MoDL/utils/subsample.py in subsample(data, mask_func, seed, mode)
#     282     mask = mask_func(mask_shape, seed)
#     283 #     print(mask.shape)
# --> 284     return torch.where(mask == 0, torch.Tensor([0]), data), mask
#     285
#     286
#
# TypeError: where(): argument 'other' (position 3) must be Tensor, not numpy.ndarray

# %%
dev_mask = VDktMaskFunc([13,15])
maps = maps[...,0][...,None]
target = target[...,0][...,None]
# Convert everything from numpy arrays to tensors
kspace = cplx.to_tensor(kspace).unsqueeze(0)
maps   = cplx.to_tensor(maps).unsqueeze(0)
target = cplx.to_tensor(target).unsqueeze(0)
norm = torch.sqrt(torch.mean(cplx.abs(target)**2))
seed = None
# kspace, target = self.augment(kspace, target, seed)
#         pl.ImagePlot(kspace)
#         pl.ImagePlot(target)
# Undersample k-space data
masked_kspace, mask = ss.subsample(kspace, dev_mask, seed)

# %%
mask.shape
# Out:
# torch.Size([1, 64, 180, 20, 1, 1])

# %%
A = T.SenseModel(maps)

# Compute normalization factor (based on 95% max signal level in view-shared dataa)
averaged_kspace = T.time_average(masked_kspace, dim=3)
image = A(averaged_kspace, adjoint=True)
magnitude_vals = cplx.abs(image).reshape(-1)
k = int(round(0.05 * magnitude_vals.numel()))
scale = torch.min(torch.topk(magnitude_vals, k).values)

# Normalize k-space and target images
masked_kspace /= scale
target /= scale
mean = torch.tensor([0.0], dtype=torch.float32)
std = scale

# %%
kspace.shape
# Out:
# torch.Size([1, 64, 180, 20, 8, 2])

# %%
pl.ImagePlot(sp.resize(adj,(64,100,20)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-458fab000b66> in <module>
# ----> 1 pl.ImagePlot(sp.resize(adj,(64,100,20)))
#
# NameError: name 'adj' is not defined

# %%
masked_kspace = masked_kspace
maps = maps
target = target

# %%
print(mask[0,30,...,0,0].numpy().sum()/(180*20))
# Out:
# 0.105

# %%
# Load the checkpoint:
# checkpoint_file = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10281_ufloss0/model_epoch1000.pt"
checkpoint_file = "/mikQNAP/cardiac_cine/summary/train-3D_MELD_10steps_2resblocks_32features_MoDLflag0_CGsteps_8date_11041_ufloss0/model_epoch500.pt"
# checkpoint_file = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10281_ufloss0/model_epoch1000.pt"

checkpoint = torch.load(checkpoint_file,map_location=device)
args = checkpoint['args']
# args.device_num='-1'
# args.device='cpu'
if args.modl_flag == True:
    if args.meld_flag == True:
#         print("f")
        model = UnrolledModelMELD(args).to(device)
    else:
        model = UnrolledModelM(args).to(device)
else:
    model = UnrolledModel(args).to(device)
model.load_state_dict(checkpoint['model'])
print(checkpoint['epoch'])
# Out:
# No shared weights
# 500

# %%
# checkpoint_file_modl = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10282_ufloss0/model_epoch1000.pt"

checkpoint_file_modl = "/mikQNAP/cardiac_cine/summary/train-3D_MELD_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_11042_ufloss0/model_epoch500.pt"
checkpoint_modl = torch.load(checkpoint_file_modl,map_location=device)
args_modl = checkpoint_modl['args']
args_modl.modl_lamda = 0.07
# args_modl.conv_type = 'conv3d'
# args_modl.device_num='-1'
# args_modl.device='cpu'
if args_modl.modl_flag == True:
    model_modl = UnrolledModelM(args_modl).to(device)
else:
    model_modl = UnrolledModel(args_modl).to(device)
model_modl.load_state_dict(checkpoint_modl['model'])
print(checkpoint_modl['epoch'])
# Out:
# No shared weights
# 500

# %%
# checkpoint_file_modl_ufloss = "/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10284_ufloss_True_convtype_conv2p1d/model_epoch1999.pt"
# 
checkpoint_file_modl_ufloss = "/home/kewang/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10283_ufloss_True_convtype_conv2p1d/model_epoch1000.pt"
checkpoint_modl_ufloss = torch.load(checkpoint_file_modl_ufloss,map_location=device)
args_modl_ufloss = checkpoint_modl_ufloss['args']
args_modl_ufloss.modl_lamda = 0.05

# args_modl_ufloss.conv_type = 'conv3d'
# args_modl_ufloss.device_num='-1'
# args_modl_ufloss.device='cpu'
if args_modl_ufloss.modl_flag == True:
    model_modl_ufloss = UnrolledModelM(args_modl_ufloss).to(device)
else:
    model_modl_ufloss = UnrolledModel(args_modl_ufloss).to(device)
model_modl_ufloss.load_state_dict(checkpoint_modl_ufloss['model'])
print(checkpoint_modl_ufloss['epoch'])
# Out:
# No shared weights
# 1000

# %%
input_torch = masked_kspace.to(device)
maps_torch = maps.to(device)
target_torch = target.to(device)

# %%
with torch.no_grad():
#     start = time.time()
    model.initiate(input_torch,maps_torch)
    start = time.time()
    output = model()
    
#     output = model(input_torch, maps_torch, init_image=None)
#     print(time.time()-start)
    start = time.time()

    output_modl = model_modl(input_torch, maps_torch, init_image=None)    
    print(time.time()-start)
# Out:
# I Love you
# I Love you
# I Love you
# I Love you
# I Love you
# I Love you
# I Love you
# I Love you
# I Love you
# I Love you
# 0.25267934799194336

# %%
with torch.no_grad():
    output_modl_ufloss = model_modl_ufloss(input_torch, maps_torch, init_image=None)

# %%
A = T.SenseModel(maps_torch)
zf_image = A(input_torch,adjoint=True)

# %%
output_np = torch2np(output)

# %%
pl.ImagePlot(output_np)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
output_np = torch2np(output)
output_modl_ufloss_np = torch2np(output_modl_ufloss)
output_modl_np = torch2np(output_modl)
output_gt = torch2np(target)
output_zf = torch2np(zf_image)
output_all = np.concatenate((output_gt,output_np,output_modl_np,output_modl_ufloss_np))

# %%
def compute_metrics(output,target_torch):
    cplx_error = cplx.abs(output - target_torch)
    cplx_l1 = torch.mean(cplx_error)
    cplx_l2 = torch.sqrt(torch.mean(cplx_error**2))
    cplx_psnr = 20 * torch.log10(scale / cplx_l2)
    return cplx_l1,cplx_l2,cplx_psnr

# %%
compute_metrics(output,target_torch)
# Out:
# (tensor(0.0414, device='cuda:0'),
#  tensor(0.0526, device='cuda:0'),
#  tensor(182.7252))

# %%
compute_metrics(output_modl,target_torch)
# Out:
# (tensor(0.0436, device='cuda:0'),
#  tensor(0.0556, device='cuda:0'),
#  tensor(182.2441))

# %%
compute_metrics(output_modl_ufloss,target_torch)
# Out:
# (tensor(0.0477, device='cuda:0'),
#  tensor(0.0601, device='cuda:0'),
#  tensor(181.5815))

# %%
np.save("output_all.npy",output_all)

# %%
patch = np.load("/home/kewang/patch_cine_1028_400_20/patch_data/0_0_310.npy")

# %%
pl.ImagePlot(patch,interpolation="lanczos")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
(np.log(1/0.05)/(2*10000))**(0.5)
# Out:
# 0.012238734153404082

# %%
output_all.shape
# Out:
# (4, 64, 180, 20, 1)

# %%
image = sp.resize(output_all,(4,64,100,20,1))

# %%
import matplotlib.pyplot as plt

# %%
k = 0
orientation = "x_t"
if k == 0:
    method = "gt"
if k == 1:
    method = "10unrolls"
if k == 2:
    method = "5unrolls"
fig, ax = plt.subplots(figsize=[6, 6])
im = abs(image)[k,32,:,:,0]
im = im.transpose(1,0)
ax.imshow(im,cmap="gray",interpolation="lanczos",clim =[0,im.max()])
ax.axis("off")
plt.savefig("Figures/2D_cardiac%s_%s.png"%(orientation,method),transparent=True, format='png',bbox_inches='tight', pad_inches=0,dpi=600,quality=95)
# Out:
# <img src="data:image/png;base64,..." width="600">
# (-0.5, 99.5, 19.5, -0.5)

# %%
pl.ImagePlot(sp.resize(output_all,(4,64,100,20,1)),interpolation="lanczos")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
input_torch.shape
# Out:
# tensor([[[[[-0.1057, -0.1347]],
#
#           [[-0.1067, -0.1170]],
#
#           [[-0.1040, -0.1251]],
#
#           ...,
#
#           [[-0.0994, -0.1283]],
#
#           [[-0.1158, -0.1394]],
#
#           [[-0.1084, -0.1458]]],
#
#
#          [[[-0.0916, -0.1445]],
#
#           [[-0.1020, -0.1759]],
#
#           [[-0.1086, -0.1519]],
#
#           ...,
#
#           [[-0.1148, -0.1750]],
#
#           [[-0.1053, -0.1544]],
#
#           [[-0.0951, -0.1587]]],
#
#
#          [[[-0.1335,  0.0226]],
#
#           [[-0.1100,  0.0152]],
#
#           [[-0.1320,  0.0156]],
#
#           ...,
#
#           [[-0.1168,  0.0008]],
#
#           [[-0.1077,  0.0238]],
#
#           [[-0.1105,  0.0315]]],
#
#
#          ...,
#
#
#          [[[-0.0780, -0.0990]],
#
#           [[-0.0523, -0.0996]],
#
#           [[-0.0854, -0.1068]],
#
#           ...,
#
#           [[-0.0732, -0.0930]],
#
#           [[-0.0608, -0.0933]],
#
#           [[-0.0683, -0.1006]]],
#
#
#          [[[-0.0600,  0.0312]],
#
#           [[-0.0536,  0.0048]],
#
#           [[-0.0539,  0.0095]],
#
#           ...,
#
#           [[-0.0500,  0.0499]],
#
#           [[-0.0322,  0.0233]],
#
#           [[-0.0333,  0.0447]]],
#
#
#          [[[-0.1191, -0.2229]],
#
#           [[-0.1263, -0.2148]],
#
#           [[-0.1444, -0.2209]],
#
#           ...,
#
#           [[-0.1156, -0.1993]],
#
#           [[-0.1156, -0.2096]],
#
#           [[-0.1148, -0.2089]]]],
#
#
#
#         [[[[-0.1085, -0.1731]],
#
#           [[-0.0884, -0.1514]],
#
#           [[-0.0796, -0.1872]],
#
#           ...,
#
#           [[-0.0809, -0.1583]],
#
#           [[-0.0809, -0.1500]],
#
#           [[-0.0781, -0.1870]]],
#
#
#          [[[-0.0770, -0.1429]],
#
#           [[-0.0835, -0.1439]],
#
#           [[-0.0823, -0.1478]],
#
#           ...,
#
#           [[-0.0848, -0.1462]],
#
#           [[-0.0956, -0.1381]],
#
#           [[-0.0786, -0.1438]]],
#
#
#          [[[-0.1297, -0.0741]],
#
#           [[-0.1274, -0.0758]],
#
#           [[-0.1403, -0.0651]],
#
#           ...,
#
#           [[-0.1377, -0.0831]],
#
#           [[-0.1157, -0.1063]],
#
#           [[-0.1181, -0.0783]]],
#
#
#          ...,
#
#
#          [[[-0.0673, -0.1540]],
#
#           [[-0.0532, -0.1554]],
#
#           [[-0.0481, -0.1472]],
#
#           ...,
#
#           [[-0.0296, -0.1347]],
#
#           [[-0.0657, -0.1412]],
#
#           [[-0.0563, -0.1262]]],
#
#
#          [[[-0.0295,  0.0373]],
#
#           [[-0.0104,  0.0213]],
#
#           [[-0.0499,  0.0375]],
#
#           ...,
#
#           [[-0.0529,  0.0473]],
#
#           [[-0.0131,  0.0345]],
#
#           [[-0.0163,  0.0407]]],
#
#
#          [[[-0.0942, -0.1823]],
#
#           [[-0.0930, -0.1977]],
#
#           [[-0.0803, -0.2138]],
#
#           ...,
#
#           [[-0.0903, -0.1819]],
#
#           [[-0.0759, -0.1794]],
#
#           [[-0.0822, -0.1765]]]],
#
#
#
#         [[[[-0.0359, -0.2220]],
#
#           [[-0.0154, -0.2472]],
#
#           [[-0.0378, -0.2825]],
#
#           ...,
#
#           [[-0.0183, -0.2639]],
#
#           [[-0.0273, -0.2623]],
#
#           [[-0.0156, -0.2576]]],
#
#
#          [[[-0.0397, -0.1436]],
#
#           [[ 0.0052, -0.1416]],
#
#           [[-0.0393, -0.1757]],
#
#           ...,
#
#           [[-0.0297, -0.1672]],
#
#           [[-0.0401, -0.1606]],
#
#           [[-0.0491, -0.1737]]],
#
#
#          [[[-0.1039, -0.2252]],
#
#           [[-0.1157, -0.2113]],
#
#           [[-0.1035, -0.2220]],
#
#           ...,
#
#           [[-0.0670, -0.1959]],
#
#           [[-0.1016, -0.2194]],
#
#           [[-0.0969, -0.2243]]],
#
#
#          ...,
#
#
#          [[[-0.0352, -0.2092]],
#
#           [[-0.0312, -0.1790]],
#
#           [[ 0.0058, -0.1663]],
#
#           ...,
#
#           [[-0.0289, -0.2068]],
#
#           [[-0.0173, -0.1872]],
#
#           [[ 0.0010, -0.1937]]],
#
#
#          [[[-0.0512,  0.0313]],
#
#           [[-0.0418,  0.0257]],
#
#           [[-0.0651,  0.0463]],
#
#           ...,
#
#           [[-0.0500,  0.0063]],
#
#           [[-0.0316,  0.0296]],
#
#           [[-0.0333,  0.0240]]],
#
#
#          [[[-0.0634, -0.1592]],
#
#           [[-0.0397, -0.1655]],
#
#           [[-0.0688, -0.1646]],
#
#           ...,
#
#           [[-0.0481, -0.1569]],
#
#           [[-0.0289, -0.1759]],
#
#           [[-0.0432, -0.1643]]]],
#
#
#
#         ...,
#
#
#
#         [[[[-0.5691, -0.1816]],
#
#           [[-0.5681, -0.1932]],
#
#           [[-0.5393, -0.1740]],
#
#           ...,
#
#           [[-0.5922, -0.1828]],
#
#           [[-0.5882, -0.2179]],
#
#           [[-0.5579, -0.1928]]],
#
#
#          [[[-0.5993, -0.2254]],
#
#           [[-0.5986, -0.2625]],
#
#           [[-0.5693, -0.2121]],
#
#           ...,
#
#           [[-0.6021, -0.2445]],
#
#           [[-0.5921, -0.2398]],
#
#           [[-0.5886, -0.2063]]],
#
#
#          [[[-0.5974, -0.2291]],
#
#           [[-0.5941, -0.2331]],
#
#           [[-0.5843, -0.2474]],
#
#           ...,
#
#           [[-0.5674, -0.2552]],
#
#           [[-0.5864, -0.2408]],
#
#           [[-0.5992, -0.2463]]],
#
#
#          ...,
#
#
#          [[[-0.5517, -0.1232]],
#
#           [[-0.5382, -0.1380]],
#
#           [[-0.5446, -0.1378]],
#
#           ...,
#
#           [[-0.5371, -0.1365]],
#
#           [[-0.5530, -0.1444]],
#
#           [[-0.5652, -0.1557]]],
#
#
#          [[[-0.5139, -0.1440]],
#
#           [[-0.5152, -0.1598]],
#
#           [[-0.5124, -0.1543]],
#
#           ...,
#
#           [[-0.5112, -0.1522]],
#
#           [[-0.5213, -0.1548]],
#
#           [[-0.5385, -0.1537]]],
#
#
#          [[[-0.5018, -0.1586]],
#
#           [[-0.5232, -0.1411]],
#
#           [[-0.5020, -0.1672]],
#
#           ...,
#
#           [[-0.5133, -0.1801]],
#
#           [[-0.5088, -0.1561]],
#
#           [[-0.5135, -0.1666]]]],
#
#
#
#         [[[[-0.5242, -0.1482]],
#
#           [[-0.5203, -0.1557]],
#
#           [[-0.5357, -0.1615]],
#
#           ...,
#
#           [[-0.5322, -0.1542]],
#
#           [[-0.5537, -0.1463]],
#
#           [[-0.5142, -0.1328]]],
#
#
#          [[[-0.5287, -0.1639]],
#
#           [[-0.5462, -0.1661]],
#
#           [[-0.5477, -0.2018]],
#
#           ...,
#
#           [[-0.5447, -0.1934]],
#
#           [[-0.5663, -0.1976]],
#
#           [[-0.5237, -0.1803]]],
#
#
#          [[[-0.5787, -0.2194]],
#
#           [[-0.5426, -0.2048]],
#
#           [[-0.5716, -0.1798]],
#
#           ...,
#
#           [[-0.5979, -0.2112]],
#
#           [[-0.5746, -0.2149]],
#
#           [[-0.5717, -0.2011]]],
#
#
#          ...,
#
#
#          [[[-0.6268, -0.1370]],
#
#           [[-0.6258, -0.1312]],
#
#           [[-0.6312, -0.1424]],
#
#           ...,
#
#           [[-0.6200, -0.1226]],
#
#           [[-0.6442, -0.1441]],
#
#           [[-0.6243, -0.1118]]],
#
#
#          [[[-0.6272, -0.1614]],
#
#           [[-0.5935, -0.1683]],
#
#           [[-0.6196, -0.1747]],
#
#           ...,
#
#           [[-0.6290, -0.1496]],
#
#           [[-0.6068, -0.1539]],
#
#           [[-0.6127, -0.1773]]],
#
#
#          [[[-0.5525, -0.1408]],
#
#           [[-0.5416, -0.1468]],
#
#           [[-0.5653, -0.1441]],
#
#           ...,
#
#           [[-0.5530, -0.1473]],
#
#           [[-0.5626, -0.1469]],
#
#           [[-0.5851, -0.1447]]]],
#
#
#
#         [[[[-0.5780, -0.1873]],
#
#           [[-0.6012, -0.1657]],
#
#           [[-0.6163, -0.1355]],
#
#           ...,
#
#           [[-0.6026, -0.1736]],
#
#           [[-0.6077, -0.1710]],
#
#           [[-0.5887, -0.1573]]],
#
#
#          [[[-0.4756, -0.1480]],
#
#           [[-0.4746, -0.1446]],
#
#           [[-0.5062, -0.1264]],
#
#           ...,
#
#           [[-0.4905, -0.1156]],
#
#           [[-0.4965, -0.1359]],
#
#           [[-0.4724, -0.1395]]],
#
#
#          [[[-0.5150, -0.1597]],
#
#           [[-0.5027, -0.1498]],
#
#           [[-0.5019, -0.1614]],
#
#           ...,
#
#           [[-0.5039, -0.1654]],
#
#           [[-0.4994, -0.1638]],
#
#           [[-0.4871, -0.1843]]],
#
#
#          ...,
#
#
#          [[[-0.6252, -0.1252]],
#
#           [[-0.6165, -0.1362]],
#
#           [[-0.6340, -0.1298]],
#
#           ...,
#
#           [[-0.6273, -0.1252]],
#
#           [[-0.6350, -0.1186]],
#
#           [[-0.6399, -0.1200]]],
#
#
#          [[[-0.6317, -0.1461]],
#
#           [[-0.6087, -0.1545]],
#
#           [[-0.6172, -0.1660]],
#
#           ...,
#
#           [[-0.6207, -0.1361]],
#
#           [[-0.6292, -0.1496]],
#
#           [[-0.6346, -0.1504]]],
#
#
#          [[[-0.6007, -0.1238]],
#
#           [[-0.5987, -0.1401]],
#
#           [[-0.6124, -0.1425]],
#
#           ...,
#
#           [[-0.6113, -0.1510]],
#
#           [[-0.6140, -0.1124]],
#
#           [[-0.6094, -0.1388]]]]], device='cuda:0')

# %%
args
# Out:
# Namespace(accelerations=[10, 15], batch_size=1, checkpoint=None, circular_pad=True, conv_type='conv2p1d', data_parallel=False, data_path='/home/kewang/cardiac_cine', device='cuda', device_num='2', drop_prob=0.0, exp_dir='/mikQNAP/cardiac_cine/summary/train-3D_5steps_2resblocks_32features_MoDLflag0_CGsteps_8date_10281_ufloss0', fix_step_size=True, kernel_size=3, loss_normalized='True', loss_type=2, loss_uflossdir=None, lr=0.0001, lr_gamma=0.5, lr_step_size=500, modl_flag=False, modl_lamda=0.05, num_cg_steps=6, num_emaps=1, num_epochs=2000, num_features=32, num_grad_steps=5, num_resblocks=2, patch_size=64, report_interval=10, resume=False, sample_rate=1.0, seed=42, share_weights=False, slwin_init=True, ufloss_weight=2, uflossfreq=10, weight_decay=0.0)

# %%
pl.ImagePlot(image)
# Out:
# <img src="data:image/png;base64,..." width="640">
